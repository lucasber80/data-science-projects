# %%
import pandas as pd
import numpy as np
import os
import re

# %%
df_nba_personal = pd.read_csv('./processed/nba_personal.csv')
df_nba_stats = pd.read_csv('./processed/nba_stats.csv')
df_nba_experience = pd.read_csv('./processed/nba_experience.csv')
df_nba_season = pd.read_csv('./processed/nba_season.csv')

# %%
df_exemplo = pd.read_csv('./dataset/results/nba_stats.csv')
# Out:
#       year           name  playerId     playerSlug positionId teamId  \
# 0     1999  Allen Iverson       366  allen-iverson         SG    PHI
# 1     2000  Allen Iverson       366  allen-iverson         SG    PHI
# 2     2001  Allen Iverson       366  allen-iverson         SG    PHI
# 3     2002  Allen Iverson       366  allen-iverson         SG    PHI
# 4     2003  Allen Iverson       366  allen-iverson         SG    PHI
# ...    ...            ...       ...            ...        ...    ...
# 8157  2023  Peyton Watson   4576087  peyton-watson          F    DEN
# 8158  2023    Josh Minott   4687718    josh-minott          F    MIN
# 8159  2023    Dalen Terry   4433159    dalen-terry          F    CHI
# 8160  2023   Ryan Rollins   4591725   ryan-rollins          G     GS
# 8161  2023  Tyrese Martin   4397179  tyrese-martin          G    ATL
#
#         status  gamesPlayed  avgMinutes  avgFouls  ...       birthdate  \
# 0     inactive         48.0   41.458332  2.041667  ...        6/7/1975
# 1     inactive         70.0   40.757140  2.314286  ...        6/7/1975
# 2     inactive         71.0   41.957745  2.070423  ...        6/7/1975
# 3     inactive         60.0   43.700000  1.700000  ...        6/7/1975
# 4     inactive         82.0   42.500000  1.817073  ...        6/7/1975
# ...        ...          ...         ...       ...  ...             ...
# 8157    active         23.0    8.086957  0.608696  ...  9/11/2002 (20)
# 8158    active         15.0    6.400000  0.666667  ...  7/25/2002 (20)
# 8159    active         38.0    5.631579  0.631579  ...  7/12/2002 (20)
# 8160    active         12.0    5.166666  0.833333  ...   7/3/2002 (21)
# 8161    active         16.0    4.125000  0.125000  ...   3/7/1999 (24)
#
#          college                draftinfo      birthplace  \
# 0     Georgetown   1996: Rd 1, Pk 1 (PHI)     Hampton, VA
# 1     Georgetown   1996: Rd 1, Pk 1 (PHI)     Hampton, VA
# 2     Georgetown   1996: Rd 1, Pk 1 (PHI)     Hampton, VA
# 3     Georgetown   1996: Rd 1, Pk 1 (PHI)     Hampton, VA
# 4     Georgetown   1996: Rd 1, Pk 1 (PHI)     Hampton, VA
# ...          ...                      ...             ...
# 8157        UCLA  2022: Rd 1, Pk 30 (OKC)  Long Beach, CA
# 8158     Memphis  2022: Rd 2, Pk 45 (CHA)  Boca Raton, FL
# 8159     Arizona  2022: Rd 1, Pk 18 (CHI)     Phoenix, AZ
# 8160      Toledo  2022: Rd 2, Pk 44 (ATL)      Macomb, MI
# 8161       UConn   2022: Rd 2, Pk 51 (GS)   Allentown, PA
#
#                         team  experience  rankingSalary       salary  weight  \
# 0                        NaN         NaN             15   $9,000,000     NaN
# 1                        NaN         NaN             27  $10,125,000     NaN
# 2                        NaN         NaN             17  $11,250,000     NaN
# 3                        NaN         NaN             14  $12,375,000     NaN
# 4                        NaN         NaN             11  $13,500,000     NaN
# ...                      ...         ...            ...          ...     ...
# 8157          Denver Nuggets      Rookie            277   $2,303,520   6' 8"
# 8158  Minnesota Timberwolves      Rookie            332   $1,719,864   6' 8"
# 8159           Chicago Bulls      Rookie            238   $3,350,760   6' 7"
# 8160   Golden State Warriors      Rookie            334   $1,719,864   6' 3"
# 8161           Atlanta Hawks      Rookie            336   $1,719,864   6' 6"
#
#        height
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 8157  200 lbs
# 8158  205 lbs
# 8159  200 lbs
# 8160  180 lbs
# 8161  215 lbs
#
# [8162 rows x 55 columns]

# %%
df_nba_personal.head()
# Out:
#   playerId     playerSlug     college               draftinfo           name  \
# 0      366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)  Allen Iverson
# 1      366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)  Allen Iverson
# 2      366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)  Allen Iverson
# 3      366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)  Allen Iverson
# 4      366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)  Allen Iverson
#
#   birthdate   birthplace  year height weight
# 0  6/7/1975  Hampton, VA  1999    NaN    NaN
# 1  6/7/1975  Hampton, VA  2000    NaN    NaN
# 2  6/7/1975  Hampton, VA  2001    NaN    NaN
# 3  6/7/1975  Hampton, VA  2002    NaN    NaN
# 4  6/7/1975  Hampton, VA  2003    NaN    NaN

# %%
df_nba_stats.head()
# Out:
# Index(['playerId', 'gamesPlayed', 'avgMinutes', 'avgFouls', 'flagrantFouls',
#        'technicalFouls', 'ejections', 'doubleDouble', 'tripleDouble',
#        'minutes', 'rebounds', 'fouls', 'avgRebounds', 'avgPoints',
#        'avgFieldGoalsMade', 'avgFieldGoalsAttempted', 'fieldGoalPct',
#        'avgThreePointFieldGoalsMade', 'avgThreePointFieldGoalsAttempted',
#        'threePointFieldGoalPct', 'avgFreeThrowsMade', 'avgFreeThrowsAttempted',
#        'freeThrowPct', 'avgAssists', 'avgTurnovers', 'points',
#        'fieldGoalsMade', 'fieldGoalsAttempted', 'threePointFieldGoalsMade',
#        'threePointFieldGoalsAttempted', 'freeThrowsMade',
#        'freeThrowsAttempted', 'assists', 'turnovers', 'avgSteals', 'avgBlocks',
#        'steals', 'blocks', 'totalPoints', 'year'],
#       dtype='object')

# %%
df_integrado = pd.merge(df_nba_personal, df_nba_season,
                        how='left', on=['playerId','year'])

df_integrado
# Out:
#      playerId     playerSlug     college               draftinfo  \
# 0         366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)
# 1         366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)
# 2         366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)
# 3         366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)
# 4         366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)
# ...       ...            ...         ...                     ...
# 8163  4397179  tyrese-martin       UConn  2022: Rd 2, Pk 51 (GS)
# 8164      366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)
# 8165      366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)
# 8166      366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)
# 8167      366  allen-iverson  Georgetown  1996: Rd 1, Pk 1 (PHI)
#
#                name      birthdate     birthplace  year height   weight  \
# 0     Allen Iverson       6/7/1975    Hampton, VA  1999    NaN      NaN
# 1     Allen Iverson       6/7/1975    Hampton, VA  1999    NaN      NaN
# 2     Allen Iverson       6/7/1975    Hampton, VA  2000    NaN      NaN
# 3     Allen Iverson       6/7/1975    Hampton, VA  2000    NaN      NaN
# 4     Allen Iverson       6/7/1975    Hampton, VA  2001    NaN      NaN
# ...             ...            ...            ...   ...    ...      ...
# 8163  Tyrese Martin  3/7/1999 (24)  Allentown, PA  2023  6' 6"  215 lbs
# 8164  Allen Iverson       6/7/1975    Hampton, VA  1999    NaN      NaN
# 8165  Allen Iverson       6/7/1975    Hampton, VA  1999    NaN      NaN
# 8166  Allen Iverson       6/7/1975    Hampton, VA  2000    NaN      NaN
# 8167  Allen Iverson       6/7/1975    Hampton, VA  2000    NaN      NaN
#
#      positionId        position teamId           team    status
# 0            SG  Shooting Guard    PHI            NaN  inactive
# 1            SG  Shooting Guard    PHI            NaN  inactive
# 2            SG  Shooting Guard    PHI            NaN  inactive
# 3            SG  Shooting Guard    PHI            NaN  inactive
# 4            SG  Shooting Guard    PHI            NaN  inactive
# ...         ...             ...    ...            ...       ...
# 8163          G           Guard    ATL  Atlanta Hawks    active
# 8164         SG  Shooting Guard    PHI            NaN  inactive
# 8165         SG  Shooting Guard    PHI            NaN  inactive
# 8166         SG  Shooting Guard    PHI            NaN  inactive
# 8167         SG  Shooting Guard    PHI            NaN  inactive
#
# [8168 rows x 15 columns]
