# %%
import pandas as pd

# %%
df_cards = pd.read_excel('dados-jogos.xlsx')
df_cards.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      18 non-null     object
#  1   link       18 non-null     object
#  2   date       18 non-null     object
#  3   size       18 non-null     object
#  4   source     18 non-null     object
#  5   image_url  18 non-null     object
# dtypes: object(6)
# memory usage: 992.0+ bytes

# %%
df_cards.head()
# Out:
#                       title                      link  \
# 0         Rise of the Ronin        /Rise-of-the-Ronin
# 1                  WWE 2K25                 /WWE-2K25
# 2             Split Fiction            /Split-Fiction
# 3  Age of Mythology: Retold  /Age-of-Mythology-Retold
# 4         Final Fantasy XVI        /FINAL-FANTASY-XVI
#
#                           date              size     source  \
# 0  ATUALIZADO EM:Mar. 11th '25   TAMANHO:60.2 GB     BYDODI
# 1   ATUALIZADO EM:Mar. 7th '25   TAMANHO:79.6 GB  BYFitGirl
# 2  ATUALIZADO EM:Mar. 06th '25   TAMANHO:56.6 GB  BYFitGirl
# 3  ATUALIZADO EM:Mar. 06th '25   TAMANHO:13.0 GB  BYFitGirl
# 4  ATUALIZADO EM:Mar. 05th '25  TAMANHO:153.2 GB     BYDODI
#
#                                            image_url
# 0  https://image.api.playstation.com/vulcan/ap/rn...
# 1  https://image.api.playstation.com/vulcan/ap/rn...
# 2  https://gaming-cdn.com/images/products/17864/6...
# 3  https://shared.akamai.steamstatic.com/store_it...
# ...

# %%
df_cards_details = pd.read_excel('dados-jogos-details.xlsx')
df_cards_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   link                       18 non-null     object
#  1   shop_src                   16 non-null     object
#  2   images_src                 18 non-null     object
#  3   description                18 non-null     object
#  4   categories                 18 non-null     object
#  5   magnet_link                18 non-null     object
#  6   trailer_src                18 non-null     object
#  7   game_minimum_requiriments  18 non-null     object
#  8   game_req_requiriments      18 non-null     object
# dtypes: object(9)
# memory usage: 1.4+ KB

# %%
df_cards_details.head()
# Out:
#                        link                                       shop_src  \
# 0        /Rise-of-the-Ronin  https://store.steampowered.com/widget/1340990
# 1                 /WWE-2K25  https://store.steampowered.com/widget/2878960
# 2            /Split-Fiction  https://store.steampowered.com/widget/2001120
# 3  /Age-of-Mythology-Retold  https://store.steampowered.com/widget/1934680
# 4        /FINAL-FANTASY-XVI  https://store.steampowered.com/widget/2515020
#
#                                           images_src  \
# 0  ['https://shared.fastly.steamstatic.com/store_...
# 1  ['https://shared.fastly.steamstatic.com/store_...
# 2  ['https://shared.fastly.steamstatic.com/store_...
# 3  ['https://shared.akamai.steamstatic.com/store_...
# 4  ['https://shared.fastly.steamstatic.com/store_...
#
#                                          description  \
# 0  Sinopse: Embarque em uma jornada épica pela Er...
# 1  Sinopse: Homenageie a Bloodline em Showcase. E...
# ...

# %%
df_merged = pd.merge(df_cards, df_cards_details, on='link', how='left')
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title                      18 non-null     object
#  1   link                       18 non-null     object
#  2   date                       18 non-null     object
#  3   size                       18 non-null     object
#  4   source                     18 non-null     object
#  5   image_url                  18 non-null     object
#  6   shop_src                   16 non-null     object
#  7   images_src                 18 non-null     object
#  8   description                18 non-null     object
#  9   categories                 18 non-null     object
#  10  magnet_link                18 non-null     object
#  11  trailer_src                18 non-null     object
#  12  game_minimum_requiriments  18 non-null     object
# ...

# %%
df_merged.to_excel('dados-jogos-completo.xlsx', index=False)
